# %%
from typing import List, Tuple, Dict
import re

# %%
class InvertedIndex:
    def __init__(self):
        self.dictionary = {}
        self.postings_lists = {}
        self.postings_list_id_counter = 0
        self.tweet_texts = {}

    def normalize_term(self, term: str) -> str:
        """
        Normalize the term by converting it to lowercase and removing any non-alphanumeric characters.
        """
        return re.sub(r"\W+", "", term.lower())
    
    def get_tweet_texts(self, tweet_ids: List[str]) -> List[str]:
        '''
        Get the text content of tweets given their IDs.
        '''
        return [self.tweet_texts[tweet_id] for tweet_id in tweet_ids if tweet_id in self.tweet_texts]

    def index(self, filename: str):
        """
        Index the documents in the given file.
        """
        with open(filename, "r", encoding="utf-8") as file:
            for line in file:
                columns = line.strip().split("\t")
                if len(columns) < 5:
                    continue
                tweet_id = columns[1]
                tweet_text = columns[4]
                self.tweet_texts[tweet_id] = tweet_text
                terms = tweet_text.split()
                unique_terms = set()
                for term in terms:
                    normalized_term = self.normalize_term(term)
                    if normalized_term and normalized_term not in unique_terms:
                        unique_terms.add(normalized_term)
                        if normalized_term not in self.dictionary:
                            postings_list_id = self.postings_list_id_counter
                            self.postings_lists[postings_list_id] = []
                            self.dictionary[normalized_term] = (0, postings_list_id)
                            self.postings_list_id_counter += 1
                        size, postings_list_id = self.dictionary[normalized_term]
                        postings_list = self.postings_lists[postings_list_id]
                        if not postings_list or postings_list[-1][0] != tweet_id:
                            postings_list.append((tweet_id, None))
                            self.dictionary[normalized_term] = (
                                size + 1,
                                postings_list_id,
                            )
                            if len(postings_list) > 1:
                                postings_list[-2] = (
                                    postings_list[-2][0],
                                    len(postings_list) - 1,
                                )

    def query(self, term: str) -> List[Tuple[str, int]]:
        """
        Query the index for a single term and return the postings list.
        """
        normalized_term = self.normalize_term(term)
        if normalized_term in self.dictionary:
            size, postings_list_id = self.dictionary[normalized_term]
            return self.postings_lists[postings_list_id]
        return []

# %%
class InvertedIndex(InvertedIndex):
    def intersect_postings_lists(
        self,
        postings_list1: List[Tuple[str, int]],
        postings_list2: List[Tuple[str, int]],
    ) -> List[str]:
        """
        Intersect two postings lists and return the common document IDs.
        """
        result = []
        iter1 = iter(postings_list1)
        iter2 = iter(postings_list2)
        posting1 = next(iter1, None)
        posting2 = next(iter2, None)
        while posting1 is not None and posting2 is not None:
            doc_id1, next_posting1 = posting1
            doc_id2, next_posting2 = posting2
            if doc_id1 == doc_id2:
                result.append(doc_id1)
                posting1 = next(iter1, None) if next_posting1 is not None else None
                posting2 = next(iter2, None) if next_posting2 is not None else None
            elif doc_id1 < doc_id2:
                posting1 = next(iter1, None) if next_posting1 is not None else None
            else:
                posting2 = next(iter2, None) if next_posting2 is not None else None
        return result

    def query(self, term1: str, term2: str = None) -> List[str]:
        """
        Query the index for one or two terms and return the document IDs.
        """
        postings_list1 = super().query(term1)
        if term2 is not None:
            postings_list2 = super().query(term2)
            return self.intersect_postings_lists(postings_list1, postings_list2)
        return [doc_id for doc_id, _ in postings_list1]

# %%
# Test the query method
index = InvertedIndex()
index.index("tweets.csv")

# %%
index.dictionary
# Out:
# {'knakatani': (11, 0),
#  'chikonjugular': (1, 1),
#  'joofford': (1, 2),
#  'steveblogs11': (1, 3),
#  'httpstcowhtarygnsy': (1, 4),
#  'says': (203, 5),
#  'lifetime': (24, 6),
#  'risk': (293, 7),
#  'of': (11572, 8),
#  'cervical': (38, 9),
#  'cancer': (685, 10),
#  'in': (20707, 11),
#  'japan': (114, 12),
#  'is': (9369, 13),
#  '1': (1448, 14),
#  '100': (470, 15),
#  'that': (8408, 16),
#  'means': (207, 17),
#  'hpv': (54, 18),
#  'endemic': (1, 19),
#  'and': (15759, 20),
#  'screening': (32, 21),
#  'not': (5413, 22),
#  'working': (222, 23),
#  'well': (1125, 24),
#  'fischerkurt': (1, 25),
#  'lady': (124, 26),
#  'whats': (235, 27),
#  'a': (13011, 28),
#  'tumor': (734, 29),
#  'kippcharts': (1, 30),
#  'kings_of_metal': (1, 31),
#  'ohne': (1044, 32),
#  'diagnoseverdacht': (1, 33),
#  'ist': (14585, 34),
#  'es': (10964, 35),
#  'nunmal': (27, 36),
#  'schwer': (250, 37),
#  'gerade': (1221, 38),
#  'für': (7771, 39),
#  'einen': (2888, 40),
#  'hausarzt': (20, 41),
#  'am': (4928, 42),
#  'blutbild': (2, 43),
#  'kann': (3715, 44),
#  'man': (5693, 45),
#  'meist': (143, 46),
#  'nicht': (11968, 47),
#  'viel': (2004, 48),
#  'sehen': (765, 49),
#  'wenn': (5124, 50),
#  'auch': (8232, 51),
#  'die': (19073, 52),
#  'hormone': (12, 53),
#  'überprüft': (15, 54),
#  'erklärbare': (1, 55),
#  'gewichtseinlagerungen': (1, 56),
#  'können': (1110, 57),
#  'ja': (4121, 58),
#  'alles': (1934, 59),
#  'sein': (2315, 60),
#  'von': (7410, 61),
#  'wasser': (194, 62),
#  'fett': (45, 63),
#  'kind': (930, 64),
#  'bis': (1067, 65),
#  'hin': (273, 66),
#  'zum': (2290, 67),
#  'germanletsplay': (103, 68),
#  'quentin34013799': (1, 69),
#  '_lopoopl_': (1, 70),
#  'levanni_': (1, 71),
#  'igeloe': (1, 72),
#  'annelle1805': (1, 73),
#  'glückwunsch': (90, 74),
#  'interesting': (152, 75),
#  'pcr': (4, 76),
#  'rate': (64, 77),
#  'at': (3687, 78),
#  'major': (78, 79),
#  'centers': (3, 80),
#  'authors': (17, 81),
#  'argue': (16, 82),
#  'with': (6181, 83),
#  'treatment': (262, 84),
#  'compliance': (16, 85),
#  'we': (2182, 86),
#  'see': (1702, 87),
#  'the': (17143, 88),
#  'same': (769, 89),
#  'our': (895, 90),
#  'database': (1, 91),
#  'i': (15340, 92),
#  'think': (1364, 93),
#  'its': (3528, 94),
#  'rather': (258, 95),
#  'due': (167, 96),
#  'to': (14630, 97),
#  'earlier': (63, 98),
#  'detection': (22, 99),
#  'smaller': (17, 100),
#  'tumors': (399, 101),
#  'more': (3152, 102),
#  'will': (3327, 103),
#  'look': (813, 104),
#  'deeper': (21, 105),
#  'into': (713, 106),
#  'this': (5927, 107),
#  'crcsm': (1, 108),
#  'httpstcoqfl5g2z5u9': (1, 109),
#  'new': (1551, 110),
#  'nanobots': (10, 111),
#  'kill': (190, 112),
#  'cancerous': (399, 113),
#  'by': (2484, 114),
#  'cutting': (14, 115),
#  'off': (687, 116),
#  'their': (1130, 117),
#  'blood': (191, 118),
#  'supply': (7, 119),
#  'httpstcog05sqiygck': (1, 120),
#  'digitaleconomy': (1, 121),
#  'february': (45, 122),
#  '19': (86, 123),
#  '2018': (753, 124),
#  '0801pm': (1, 125),
#  'rip': (102, 126),
#  'salemnewline2003': (1, 127),
#  '1922018newlineaufgrund': (1, 128),
#  'eines': (483, 129),
#  'eingeschläfert': (4, 130),
#  'httpstcoegthscytx7': (1, 131),
#  'cancerfighting': (4, 132),
#  'nanorobots': (9, 133),
#  'programmed': (5, 134),
#  'seek': (38, 135),
#  'destroy': (49, 136),
#  'study': (328, 137),
#  'shows': (170, 138),
#  'first': (1033, 139),
#  'applications': (16, 140),
#  'dna': (52, 141),
#  'origami': (4, 142),
#  'for': (7823, 143),
#  'nanomedicine': (4, 144),
#  'httpstcobe3lxrmtsb': (1, 145),
#  'nanoroboter': (6, 146),
#  'schrumpfen': (5, 147),
#  'tumore': (8, 148),
#  'medtech': (9, 149),
#  'httpstcox3aqiwjnqb': (1, 150),
#  'rip_tear': (1, 151),
#  'tumorsnewlinedat': (1, 152),
#  'leg': (35, 153),
#  'straight': (68, 154),
#  'mccain': (6, 155),
#  'quote': (137, 156),
#  'one': (2319, 157),
#  'statement': (84, 158),
#  'about': (3541, 159),
#  'cancers': (231, 160),
#  'joyannreid': (6, 161),
#  'pampylu': (1, 162),
#  'you': (8646, 163),
#  'are': (4347, 164),
#  'wrong': (343, 165),
#  'if': (2644, 166),
#  'trump': (390, 167),
#  'probleme': (248, 168),
#  'he': (2440, 169),
#  'mere': (12, 170),
#  'small': (229, 171),
#  'symptom': (30, 172),
#  'systematic': (37, 173),
#  'ask': (222, 174),
#  'antigunkids': (1, 175),
#  'go': (1065, 176),
#  'httpstcosrkhmupyic': (1, 177),
#  'up': (1703, 178),
#  'failures': (5, 179),
#  'us': (1022, 180),
#  'democracy': (22, 181),
#  'erstmal': (217, 182),
#  'nen': (435, 183),
#  'anti': (77, 184),
#  'stick': (37, 185),
#  'lunge': (92, 186),
#  'reintherapieren': (2, 187),
#  'usa': (424, 188),
#  'upi': (52, 189),
#  'news': (822, 190),
#  'broadcast': (105, 191),
#  'emet_news_press': (91, 192),
#  'obesity': (352, 193),
#  'may': (433, 194),
#  'cause': (489, 195),
#  'sudden': (44, 196),
#  'cardiac': (59, 197),
#  'arrest': (14, 198),
#  'young': (187, 199),
#  'people': (2342, 200),
#  'high': (281, 201),
#  'pressure': (37, 202),
#  'play': (633, 203),
#  'much': (1884, 204),
#  'greater': (25, 205),
#  'role': (101, 206),
#  'among': (83, 207),
#  'than': (1136, 208),
#  'previously': (19, 209),
#  'thought': (458, 210),
#  'ne': (1123, 211),
#  'httpstcobu3k0fzody': (1, 212),
#  'leseempfehlung': (10, 213),
#  'extraordinary': (18, 214),
#  'correlation': (10, 215),
#  'between': (252, 216),
#  'social': (222, 217),
#  'inequality': (4, 218),
#  'httpstcogywbmx0lh7': (1, 219),
#  'fazefuzzface': (1, 220),
#  'welcome': (134, 221),
#  'isonnylucas': (1, 222),
#  'thats': (1220, 223),
#  'exactly': (158, 224),
#  'point': (286, 225),
#  'whataboutism': (8, 226),
#  'dont': (2902, 227),
#  'want': (1230, 228),
#  'face': (325, 229),
#  'problem': (659, 230),
#  'worse': (173, 231),
#  'bnewlinefollowing': (1, 232),
#  'logic': (18, 233),
#  'yes': (598, 234),
#  'opioid': (7, 235),
#  'crisis': (25, 236),
#  'bad': (948, 237),
#  'but': (6900, 238),
#  'what': (2465, 239),
#  'affects': (32, 240),
#  'way': (929, 241),
#  'children': (248, 242),
#  'many': (849, 243),
#  'deathsnewlinelike': (1, 244),
#  'never': (1091, 245),
#  'solve': (27, 246),
#  'any': (761, 247),
#  'obese': (877, 248),
#  'adult': (484, 249),
#  'free': (644, 250),
#  'online': (449, 251),
#  'mobile': (93, 252),
#  'sex': (1596, 253),
#  'httpstcomcluavuvra': (1, 254),
#  'ebony': (17, 255),
#  'porn': (659, 256),
#  'carrie': (7, 257),
#  'fisher': (18, 258),
#  'naked': (357, 259),
#  'pictures': (191, 260),
#  'httpstcojqd1utavna': (1, 261),
#  'obese_to_beast': (4, 262),
#  'sad': (4794, 263),
#  'days': (455, 264),
#  'cant': (1343, 265),
#  'get': (2385, 266),
#  'stuff': (396, 267),
#  'like': (3903, 268),
#  'reducing': (21, 269),
#  'damage': (57, 270),
#  'when': (2315, 271),
#  'just': (5558, 272),
#  'doesnt': (580, 273),
#  'move': (120, 274),
#  'your': (2632, 275),
#  'fat': (180, 276),
#  'big': (497, 277),
#  'booty': (13, 278),
#  'asians': (3, 279),
#  'fucking': (1833, 280),
#  'httpstcoaqsrenqkpj': (1, 281),
#  'gallery': (64, 282),
#  'how': (2052, 283),
#  'overcome': (26, 284),
#  'addiction': (18, 285),
#  'httpstcosxne7yjxuz': (1, 286),
#  'amateur': (98, 287),
#  'downblouse': (1, 288),
#  'videos': (409, 289),
#  'can': (2251, 290),
#  'hiv': (746, 291),
#  'through': (391, 292),
#  'oral': (179, 293),
#  'httpstco7cpucmamr4': (4, 294),
#  'und': (20528, 295),
#  'syphilis': (22, 296),
#  'kommt': (1161, 297),
#  'wiedernewlineja': (1, 298),
#  'eine': (4965, 299),
#  'preptherapie': (1, 300),
#  'das': (15871, 301),
#  'übertragungsinfektionsrisiko': (1, 302),
#  'auf': (7202, 303),
#  'nahezu': (26, 304),
#  'null': (66, 305),
#  'senkennewlineaber': (1, 306),
#  'der': (15324, 307),
#  'kleine': (322, 308),
#  'ficker': (5, 309),
#  'schon': (3641, 310),
#  'längst': (69, 311),
#  'wieder': (2549, 312),
#  'danewlinesyphilis': (1, 313),
#  'tut': (416, 314),
#  'anfang': (187, 315),
#  'weh': (101, 316),
#  'aber': (6782, 317),
#  'ende': (514, 318),
#  'beißt': (13, 319),
#  'sie': (5526, 320),
#  'einem': (1572, 321),
#  'doch': (2419, 322),
#  'den': (7056, 323),
#  'arsch': (121, 324),
#  'u': (896, 325),
#  'gif': (77, 326),
#  'teens': (96, 327),
#  'httpstcot02kwb6pp1': (1, 328),
#  'anal': (276, 329),
#  'nudeteenpussyvideos': (1, 330),
#  'httpstcojxtn0dpfqt': (1, 331),
#  'scare': (15, 332),
#  'bondage': (11, 333),
#  'httpstcogkywispdi9': (1, 334),
#  'unbelievable': (37, 335),
#  'transformation': (40, 336),
#  'after': (1160, 337),
#  'dementia': (260, 338),
#  'patients': (260, 339),
#  'given': (66, 340),
#  'baby': (323, 341),
#  'dolls': (5, 342),
#  'httpstcocqgxdqctjk': (1, 343),
#  'pupaid': (1, 344),
#  'judysale23': (1, 345),
#  'oldiesclub': (1, 346),
#  '_animaladvocate': (1, 347),
#  'lucy_cavalier': (1, 348),
#  'foarctwales': (1, 349),
#  'victorias': (3, 350),
#  'cariadcampaign': (1, 351),
#  'animal_watch': (1, 352),
#  'the_animal_team': (1, 353),
#  'peteregan6': (1, 354),
#  'findingsheltera': (1, 355),
#  'gailporter': (1, 356),
#  'sisi': (2, 357),
#  'had': (1465, 358),
#  'progressed': (5, 359),
#  'all': (3404, 360),
#  'horrible': (85, 361),
#  'symptoms': (157, 362),
#  'zero': (59, 363),
#  'quality': (89, 364),
#  'life': (1370, 365),
#  'her': (1629, 366),
#  'last': (778, 367),
#  'weeksmonths': (1, 368),
#  'crossed': (23, 369),
#  'bridge': (34, 370),
#  'peacefully': (6, 371),
#  'on': (5090, 372),
#  '5th': (20, 373),
#  'january': (21, 374),
#  'adopted': (14, 375),
#  'from': (2471, 376),
#  'my': (6657, 377),
#  'mum': (112, 378),
#  'who': (1548, 379),
#  'retirement': (5, 380),
#  'summer': (709, 381),
#  '2014': (79, 382),
#  'sonst': (531, 383),
#  'kümmern': (44, 384),
#  'sich': (5273, 385),
#  'immer': (3007, 386),
#  'um': (2548, 387),
#  'ihre': (867, 388),
#  'gäste': (64, 389),
#  'heute': (2308, 390),
#  'haben': (3289, 391),
#  'gastronomen': (1, 392),
#  'bei': (4388, 393),
#  'ihrem': (252, 394),
#  'ball': (74, 395),
#  'hannover': (172, 396),
#  'selbst': (1102, 397),
#  'einmal': (479, 398),
#  'krachen': (6, 399),
#  'lassen': (622, 400),
#  'httpstcovjkhdlnkww': (1, 401),
#  'swiss': (94, 402),
#  'league': (119, 403),
#  'lausanne': (11, 404),
#  'hc': (39, 405),
#  'has': (1421, 406),
#  'reportedly': (7, 407),
#  'acquired': (11, 408),
#  'blicenses': (1, 409),
#  'four': (64, 410),
#  'hcc': (238, 411),
#  'players': (110, 412),
#  'lhc': (4, 413),
#  'httpstcoq5nvykkdkg': (1, 414),
#  'design': (211, 415),
#  'oct': (9, 416),
#  'porcelain': (9, 417),
#  'coffee': (282, 418),
#  'dripper': (20, 419),
#  'based': (125, 420),
#  'octagon': (2, 421),
#  'clean': (49, 422),
#  'lines': (47, 423),
#  'httpstcor2h5yuxlhq': (1, 424),
#  'kinto': (49, 425),
#  'kollektion': (14, 426),
#  'przellan': (4, 427),
#  'kaffeefilter': (61, 428),
#  'zu': (9783, 429),
#  '4': (753, 430),
#  'tassen': (39, 431),
#  'beliebtnewline2895newline': (1, 432),
#  'httpstcofa3zxnwtlnnewlinevia': (1, 433),
#  'outfy': (225, 434),
#  'httpstcozai9omqfio': (1, 435),
#  'findet': (271, 436),
#  'alljährliche': (2, 437),
#  'festival': (97, 438),
#  'sinne': (82, 439),
#  'im': (14636, 440),
#  'statt': (225, 441),
#  'wir': (3731, 442),
#  'freuen': (189, 443),
#  'uns': (1636, 444),
#  'als': (33846, 445),
#  'sponsor': (22, 446),
#  'dabei': (694, 447),
#  'httpstcozef6wyigea': (1, 448),
#  'dazzling': (13, 449),
#  'lucy': (16, 450),
#  'httpstcorrue08kzpk': (1, 451),
#  'sm32696077': (1, 452),
#  'ニコニコ動画newlineymoみを感じた': (1, 453),
#  'httpstcoaleabsvsls': (1, 454),
#  'insolvenzverwalter': (1, 455),
#  'görg': (1, 456),
#  'fordert': (42, 457),
#  'anlegern': (1, 458),
#  'des': (1942, 459),
#  'schiffsfonds': (1, 460),
#  'ms': (123, 461),
#  'ile': (49, 462),
#  'de': (977, 463),
#  'ischia': (1, 464),
#  'ausschüttungen': (1, 465),
#  'zurück': (406, 466),
#  'recht': (501, 467),
#  'httpstcom0ahovs8nk': (1, 468),
#  'gesellschaftsrecht': (1, 469),
#  '1864': (1, 470),
#  'wörter': (49, 471),
#  'nude': (435, 472),
#  'world': (759, 473),
#  'hot': (324, 474),
#  'tan': (16, 475),
#  'girl': (892, 476),
#  'fucked': (130, 477),
#  'httpstcoifomuwxgrf': (1, 478),
#  'httpstcojivvhnncqa': (1, 479),
#  'excellent': (57, 480),
#  'read': (414, 481),
#  'michael': (113, 482),
#  'j': (67, 483),
#  'la': (531, 484),
#  'merced': (1, 485),
#  'york': (66, 486),
#  'timesnewlinehttpstconwmjqlynwx': (1, 487),
#  'uyxulxtfcbjgmqgiycyjofxnmsqmcpjahujnzxpgjgqwexuslpdcvgxhmnvnrdhbuhkrmviigcwwgmzosuyqckdzejavconsj': (1,
#   488),
#  'bngijcszbgs': (1, 489),
#  'ejctqevpneura': (1, 490),
#  'grtt': (1, 491),
#  'pregnant': (44, 492),
#  'duchess': (1, 493),
#  'cambridge': (10, 494),
#  'hosts': (23, 495),
#  'commonwealth': (1, 496),
#  'bfashionb': (30, 497),
#  'exchange': (19, 498),
#  'buckingham': (1, 499),
#  'httpstcospezf0cihu': (1, 500),
#  'weatherwatch': (1, 501),
#  'shines': (2, 502),
#  'light': (156, 503),
#  'climate': (26, 504),
#  'change': (306, 505),
#  'httpstconwswyutapm': (1, 506),
#  'black': (281, 507),
#  'panthers': (3, 508),
#  'opening': (47, 509),
#  'weekend': (421, 510),
#  'was': (9812, 511),
#  'celebration': (23, 512),
#  'african': (24, 513),
#  'httpstcovyowbe3w36': (1, 514),
#  'key': (80, 515),
#  'account': (289, 516),
#  'managerin': (4, 517),
#  'großkunden': (1, 518),
#  'handwerk': (28, 519),
#  'industrie': (18, 520),
#  'ingredients': (6, 521),
#  'httpstcom66odtdf9s': (1, 522),
#  'ingerimm': (1, 523),
#  'gaiasangel': (1, 524),
#  'schwarze': (57, 525),
#  'auge': (72, 526),
#  'dsa': (4, 527),
#  't': (144, 528),
#  'httpstco8bp4s8ihs5': (1, 529),
#  'stars': (68, 530),
#  'mailänder': (1, 531),
#  'modewoche': (1, 532),
#  'httpstcolzhv7szfgw': (1, 533),
#  'kapler': (1, 534),
#  'brings': (33, 535),
#  'perfect': (205, 536),
#  'drive': (83, 537),
#  'home': (453, 538),
#  'be': (4576, 539),
#  'bold': (17, 540),
#  'mentality': (7, 541),
#  'httpstcoyzayfgcywk': (1, 542),
#  'abcd': (31, 543),
#  'killershark': (2, 544),
#  'httpstcoc92fnjjveq': (31, 545),
#  'sega': (11, 546),
#  'cd': (196, 547),
#  'model': (247, 548),
#  '2': (1850, 549),
#  'system': (353, 550),
#  'console': (26, 551),
#  'bundle': (12, 552),
#  'tested': (20, 553),
#  'withsega': (1, 554),
#  'genesis': (8, 555),
#  'original': (180, 556),
#  'retrogaming': (22, 557),
#  'ebay': (56, 558),
#  'httpstcoeepo5tv27f': (1, 559),
#  'httpstcocpidtuvlir': (1, 560),
#  'game': (685, 561),
#  'bmodeb': (2, 562),
#  'idea': (228, 563),
#  'httpstcognwbvxnwh8': (1, 564),
#  'neue': (857, 565),
#  'bundesstraße': (1, 566),
#  'lebenspläne': (1, 567),
#  'zerstört': (59, 568),
#  'httpstco9o2hjxyg4y': (1, 569),
#  'hamburg': (265, 570),
#  'dein': (662, 571),
#  'engagement': (35, 572),
#  'httpstco4wxqgz1s9e': (1, 573),
#  'vermisster': (1, 574),
#  'schotte': (2, 575),
#  'spürhund': (1, 576),
#  'sucht': (135, 577),
#  'michel': (6, 578),
#  'nach': (2341, 579),
#  'liam': (23, 580),
#  'httpstco45lchsias5': (1, 581),
#  'digimon': (18, 582),
#  'story': (425, 583),
#  'cyber': (8, 584),
#  'sleuth': (1, 585),
#  'hackers': (2, 586),
#  'memory': (48, 587),
#  'abgedrehtes': (2, 588),
#  'abenteuer': (67, 589),
#  'zwischen': (255, 590),
#  'cyberspace': (1, 591),
#  'httpstconbe0hxzulc': (1, 592),
#  'tommy_potti': (1, 593),
#  'hey': (430, 594),
#  'potti': (1, 595),
#  'fan': (290, 596),
#  'since': (598, 597),
#  'early': (143, 598),
#  'cs': (192, 599),
#  'always': (972, 600),
#  'watching': (281, 601),
#  'yt': (86, 602),
#  'pubg': (104, 603),
#  'wondering': (47, 604),
#  'video': (1489, 605),
#  'settings': (12, 606),
#  'fov': (2, 607),
#  'cuz': (92, 608),
#  'image': (94, 609),
#  'looks': (490, 610),
#  'so': (16663, 611),
#  'crispy': (3, 612),
#  'pls': (132, 613),
#  'dm': (388, 614),
#  'would': (1521, 615),
#  'nice': (763, 616),
#  'ty': (24, 617),
#  'sunchayn_': (1, 618),
#  'nsjjsjs': (1, 619),
#  'ilysm': (7, 620),
#  'cute': (513, 621),
#  'adorable': (55, 622),
#  'glad': (196, 623),
#  'met': (168, 624),
#  'here': (853, 625),
#  'joined': (25, 626),
#  'asd': (91, 627),
#  'time': (1812, 628),
#  'guess': (400, 629),
#  'didnt': (1027, 630),
#  'it': (7389, 631),
#  'funk': (17, 632),
#  'rauchwarnmelder': (4, 633),
#  'asd10qr': (4, 634),
#  'installation': (12, 635),
#  'vernetzung': (9, 636),
#  'test': (201, 637),
#  'httpstco1dsv8qrqe6': (1, 638),
#  'ich': (19224, 639),
#  'mag': (1208, 640),
#  'youtubevideo': (729, 641),
#  'httpstcoebyym7ah6h': (1, 642),
#  'bananatic_com': (1, 643),
#  'autismactionco': (4, 644),
#  'replebsock': (4, 645),
#  'funny': (351, 646),
#  'being': (999, 647),
#  'able': (332, 648),
#  'write': (127, 649),
#  'short': (132, 650),
#  'memos': (2, 651),
#  'considered': (32, 652),
#  'measurement': (4, 653),
#  'autism': (596, 654),
#  'severity': (12, 655),
#  'btw': (206, 656),
#  'lack': (95, 657),
#  'aware': (76, 658),
#  'there': (1577, 659),
#  'lot': (651, 660),
#  'nonverbal': (5, 661),
#  'autistics': (13, 662),
#  'converse': (4, 663),
#  'quite': (838, 664),
#  'fluently': (5, 665),
#  'via': (1703, 666),
#  'text': (145, 667),
#  'im8d_xd': (6, 668),
#  'xd': (964, 669),
#  'other': (967, 670),
#  'side': (195, 671),
#  'pep': (13, 672),
#  'did': (886, 673),
#  'sell': (69, 674),
#  'salah': (11, 675),
#  'bruyne': (7, 676),
#  'lukaku': (2, 677),
#  'chelsea': (9, 678),
#  'bought': (102, 679),
#  'them': (1419, 680),
#  'back': (903, 681),
#  'his': (1476, 682),
#  'current': (94, 683),
#  'club': (101, 684),
#  'somehow': (133, 685),
#  'player': (172, 686),
#  'list': (100, 687),
#  'xyliser': (1, 688),
#  'mks_m8': (1, 689),
#  'teamsoxe': (2, 690),
#  'claimvictory': (1, 691),
#  'bbc': (41, 692),
#  'scientists': (63, 693),
#  'take': (580, 694),
#  'steps': (30, 695),
#  'towards': (93, 696),
#  'biological': (19, 697),
#  'httpstcoruxeu0jbdv': (1, 698),
#  'unsealed_blade': (1, 699),
#  'komm': (157, 700),
#  'autistic': (589, 701),
#  'army': (107, 702),
#  'call': (246, 703),
#  'pisfool': (1, 704),
#  'memessurreal': (1, 705),
#  'forgot': (95, 706),
#  'isnt': (389, 707),
#  'or': (2230, 708),
#  'do': (2261, 709),
#  'arbitrary': (1, 710),
#  'borders': (12, 711),
#  'keep': (381, 712),
#  'those': (581, 713),
#  'opinion': (105, 714),
#  'having': (504, 715),
#  'say': (769, 716),
#  'screeching': (23, 717),
#  'httpstcoej7gfl6iww': (1, 718),
#  'person': (828, 719),
#  'followed': (55, 720),
#  'challengenewlinesay': (1, 721),
#  'no': (2139, 722),
#  'morenewlinenewlineso': (1, 723),
#  'suffering': (86, 724),
#  'shitty': (55, 725),
#  'society': (102, 726),
#  'let': (373, 727),
#  'me': (5819, 728),
#  'exist': (63, 729),
#  'happilynewlinenewlineand': (1, 730),
#  'also': (2726, 731),
#  'an': (6525, 732),
#  'waynewlinenewlinehttpstcos9cswrgiod': (1, 733),
#  'teachers': (26, 734),
#  'found': (466, 735),
#  'out': (1849, 736),
#  'today': (1125, 737),
#  'wow': (573, 738),
#  'awkwardnewlinenewline': (1, 739),
#  'still': (1605, 740),
#  'though': (452, 741),
#  'stupid': (215, 742),
#  'nigga': (11, 743),
#  'habe': (3051, 744),
#  'ein': (8249, 745),
#  'einer': (2287, 746),
#  'youtubeplaylist': (268, 747),
#  'hinzugefügt': (272, 748),
#  'httpstcouug9ujuhnm': (1, 749),
#  'robert': (57, 750),
#  'tepper': (1, 751),
#  'easy': (159, 752),
#  'skype': (28, 753),
#  'prank': (18, 754),
#  'gone': (138, 755),
#  'son': (198, 756),
#  'fascinated': (8, 757),
#  'numbers': (33, 758),
#  'ke': (9, 759),
#  'sara': (7, 760),
#  'din': (20, 761),
#  'digital': (102, 762),
#  'gharri': (1, 763),
#  'aagay': (1, 764),
#  'kharra': (1, 765),
#  'ho': (16, 766),
#  'se': (166, 767),
#  'bht': (1, 768),
#  'mze': (1, 769),
#  'ki': (40, 770),
#  'baatayn': (1, 771),
#  'krta': (1, 772),
#  'rehta': (1, 773),
#  'love': (8873, 774),
#  'observing': (9, 775),
#  'him': (1284, 776),
#  'monocytes': (4, 777),
#  'shed': (22, 778),
#  'melanoma': (110, 779),
#  'therapy': (135, 780),
#  'sciencenewlinehttpstcotqdvuvnig0': (1, 781),
#  'httpstcoddx9fyv2ea': (1, 782),
#  'huntington': (147, 783),
#  'secret': (93, 784),
#  'cooling': (2, 785),
#  'brain': (297, 786),
#  'inflammation': (499, 787),
#  'naturally': (17, 788),
#  'food': (358, 789),
#  'httpstconcw3rwrcmr': (1, 790),
#  'data': (124, 791),
#  'refute': (5, 792),
#  'assumption': (4, 793),
#  'negative': (93, 794),
#  'newlinenewlineissls': (1, 795),
#  'prize': (15, 796),
#  'clinical': (78, 797),
#  'science': (99, 798),
#  'longitudinal': (2, 799),
#  'analysis': (79, 800),
#  'inflammatory': (19, 801),
#  'psychological': (30, 802),
#  'sleeprelated': (1, 803),
#  'factors': (40, 804),
#  'following': (110, 805),
#  'acute': (80, 806),
#  'lbp': (2, 807),
#  'episodethe': (1, 808),
#  'good': (1660, 809),
#  'uglynewlinenewlinehttpstco7yqii2iumv': (1, 810),
#  'httpstcocbtoe7sjei': (1, 811),
#  'as': (2471, 812),
#  'possible': (169, 813),
#  'link': (193, 814),
#  'dyslipidemia': (2, 815),
#  'alzheimers': (36, 816),
#  'disease': (180, 817),
#  'pubmed': (47, 818),
#  'ncbi': (45, 819),
#  'httpstcoirvckoowcx': (1, 820),
#  'healthy': (191, 821),
#  'aging': (18, 822),
#  'interplay': (5, 823),
#  'reactive': (4, 824),
#  'species': (37, 825),
#  'energy': (147, 826),
#  'httpstcoeuurvm2vn9': (1, 827),
#  'asian': (51, 828),
#  'orgies': (1, 829),
#  'nak': (2, 830),
#  'ed': (303, 831),
#  'vi': (27, 832),
#  'rgin': (1, 833),
#  'httpstcomenjd7lgtz': (1, 834),
#  'shinnzlenator': (8, 835),
#  'ed_b4ng3r': (98, 836),
#  'eifersüchtig': (8, 837),
#  'superdry': (11, 838),
#  'angebote': (65, 839),
#  'sd': (188, 840),
#  'sport': (256, 841),
#  'leggings': (13, 842),
#  'mit': (9708, 843),
#  'farbblockdesign': (2, 844),
#  'category': (46, 845),
#  'damen': (53, 846),
#  'jogginghosen': (5, 847),
#  'sportleggings': (2, 848),
#  'item': (43, 849),
#  'number': (133, 850),
#  '2123631000204kc8003': (1, 851),
#  'price': (97, 852),
#  '3497': (2, 853),
#  'ship': (78, 854),
#  '000': (38, 855),
#  'artist': (149, 856),
#  'availability': (26, 857),
#  'stock': (54, 858),
#  'neueste': (17, 859),
#  'sportkollektion': (2, 860),
#  'httpstcobmdwxcenzb': (1, 861),
#  'mode': (105, 862),
#  'httpstcoj9auwhrpxp': (1, 863),
#  'schöne': (234, 864),
#  'welt': (995, 865),
#  'httpstco1gt6nnc1sq': (1, 866),
#  'human': (292, 867),
#  'body': (357, 868),
#  'made': (778, 869),
#  '90': (114, 870),
#  'water': (147, 871),
#  'basically': (88, 872),
#  'cucumbers': (1, 873),
#  'anxiety': (394, 874),
#  'currently': (104, 875),
#  'looking': (330, 876),
#  'psychologist': (6, 877),
#  'bc': (694, 878),
#  'need': (847, 879),
#  'help': (609, 880),
#  'depression': (227, 881),
#  'id': (391, 882),
#  'talk': (459, 883),
#  'someone': (623, 884),
#  'feel': (1070, 885),
#  'keeps': (77, 886),
#  'getting': (637, 887),
#  'head': (239, 888),
#  'place': (259, 889),
#  'tbh': (342, 890),
#  'lost': (253, 891),
#  'parents': (187, 892),
#  'know': (2111, 893),
#  'burden': (15, 894),
#  'already': (651, 895),
#  'fuck': (522, 896),
#  'mood': (187, 897),
#  'solid': (69, 898),
#  'secs': (7, 899),
#  'couple': (202, 900),
#  'hours': (253, 901),
#  'ago': (339, 902),
#  'now': (2732, 903),
#  'anymore': (396, 904),
#  'catching': (15, 905),
#  'wäre': (1578, 906),
#  'ordnung': (70, 907),
#  'arthrose': (32, 908),
#  'natürliche': (27, 909),
#  'weise': (89, 910),
#  'behandeln': (66, 911),
#  'könntennewlinehttpstcoh6m1z921cnnewlinemit': (13, 912),
#  'freundlichen': (16, 913),
#  'grüßen': (34, 914),
#  'newlinehorst': (13, 915),
#  'ringel': (10, 916),
#  'newlinenewlinewould': (9, 917),
#  'right': (1253, 918),
#  'could': (1053, 919),
#  'treat': (175, 920),
#  'osteoarthritis': (242, 921),
#  'naturallynewlinehttpstcoe4lmjkf4tpnewlinegod': (9, 922),
#  'bless': (75, 923),
#  'younewlinehorst': (47, 924),
#  'affect': (40, 925),
#  'incident': (17, 926),
#  'participation': (10, 927),
#  'restriction': (2, 928),
#  'adults': (327, 929),
#  'knee': (134, 930),
#  'osteoarthritisnewlinenewlinehttpstcoj9sf8wesly': (1, 931),
#  'httpstcou0xixgoeou': (1, 932),
#  'sercanhamzaolu': (1, 933),
#  'tolgakbts': (1, 934),
#  'oa_bak': (40, 935),
#  'yalakasin': (1, 936),
#  'sercan': (1, 937),
#  'seni': (17, 938),
#  'takip': (7, 939),
#  'ediyorum': (7, 940),
#  'cünki': (1, 941),
#  'dönekligini': (1, 942),
#  'gün': (20, 943),
#  'gösteren': (1, 944),
#  'arkasina': (1, 945),
#  'özür': (1, 946),
#  'dileyip': (1, 947),
#  'tweet': (513, 948),
#  'silen': (1, 949),
#  'hür': (1, 950),
#  'zeka': (2, 951),
#  'olamayan': (1, 952),
#  'bir': (133, 953),
#  'kalemsin': (1, 954),
#  'güc': (1, 955),
#  'nerde': (4, 956),
#  'orda': (3, 957),
#  'automationnews': (6, 958),
#  'erster': (171, 959),
#  '40': (191, 960),
#  'hackathon': (2, 961),
#  'bremen': (47, 962),
#  'entwicklercommunity': (1, 963),
#  'aus': (3432, 964),
#  'region': (49, 965),
#  'traf': (13, 966),
#  'vergangenen': (32, 967),
#  'wochenende': (371, 968),
#  '161822018': (1, 969),
#  'ersten': (454, 970),
#  '14': (200, 971),
#  'teams': (70, 972),
#  'zeigten': (2, 973),
#  'dem': (3948, 974),
#  'programmiermarathon': (1, 975),
#  'kr': (2, 976),
#  'httpstcoepthx6fcmt': (1, 977),
#  'seals132': (1, 978),
#  'e': (404, 979),
#  'depois': (2, 980),
#  'dizem': (1, 981),
#  'que': (246, 982),
#  'oa': (139, 983),
#  'adversaios': (1, 984),
#  'é': (34, 985),
#  'tenhem': (1, 986),
#  'tempo': (12, 987),
#  'desconto': (1, 988),
#  'ate': (26, 989),
#  'marcar': (1, 990),
#  'noch': (5403, 991),
#  'jemand': (581, 992),
#  'zweifel': (32, 993),
#  'daran': (323, 994),
#  'dass': (4540, 995),
#  'queen': (78, 996),
#  'massiven': (6, 997),
#  'einfluss': (33, 998),
#  'hip': (496, 999),
#  ...}

# %%
resp = index.query("cancer", "vaccine")

print(resp)

index.get_tweet_texts(resp)
# Out:
# ['968924030798581762', '971150719981113344', '979336440797638656']
# ['Cancer ‘vaccine’ eradicates tumors in mice, holds promise in humans - https://t.co/hLSVBUrN8w via @Shareaholic',
#  'Australia could become first country to eradicate cervical cancer. Free HPV vaccine program in schools has led to a dramatic decline in future cervical cancer rates.  HPV (human papillomavirus) is a sexually transmitted infection that causes 99.9% of cervical cancers.#TheGuardian',
#  "A Cancer 'Vaccine' Cured 97% of Tumors in Mice. What's That Mean for People? https://t.co/W08njxJXuD"]

# %%
# (side effects and malaria vaccines) or (side effects and covid vaccines)

resp = index.query("Corona")

print(resp)
# Out:
# ['1017787802946293761']
